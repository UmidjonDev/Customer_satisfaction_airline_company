# %% [markdown]
# ### This jupyter notebook contains the code for uploading file for customer satisfaction model and predictions of the customer data in the test.csv file.

# %% [markdown]
# ### **Author : Umidjon Sattorov student at Mohirdev platform and machine learning engineer.**

# %%
#Importing necessary modules and libraries
#Data preprocessing 
import pandas as pd 
import numpy as np 

#Pipeline loader
import dill

# %%
#Loading model and test dataframe 
df_test = pd.read_csv(filepath_or_buffer = './data/imputed_test_dataset.csv')
pipe = dill.load(open('./pipeline/models/customer_satisfaction.pkl', mode = 'rb'))
print("Model loaded successfully ! ")
df_test.head()
# Out:
# Model loaded successfully !
#    id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0   1  Female  Loyal Customer   25  Personal Travel       Eco
# 1   2  Female  Loyal Customer   49  Business travel  Business
# 2   3    Male  Loyal Customer   51  Business travel  Business
# 3   4    Male  Loyal Customer   34  Business travel  Eco Plus
# 4   5    Male  Loyal Customer   34  Personal Travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             2704                      2                                  2
# 1             1623                      1                                  1
# 2              338                      4                                  4
# 3               95                      0                                  0
# 4              602                      4                                  4
#
#    Ease of Online booking  ...  Seat comfort  Inflight entertainment  \
# ...

# %%
model = pipe['model']
result = {
    'id' : df_test['id'],
    'predictions' : model.predict(X = df_test)
}
predictions_df = pd.DataFrame(data = result)
predictions_df.to_excel('./result/my_model_predictions.xlsx', index = False)
print("Submission file is saved successfully in the folder result !")
predictions_df.head(10)
# Out:
# c:\Users\User\Desktop\DataScience\Data_Analytics\Course_Project_Data_Analysis\Mohirdev_Task_2_Certification\pipeline\pipeline.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Customer Type'] = df['Customer Type'].apply(lambda x : 1 if x == 'Loyal Customer' else 0)
# c:\Users\User\Desktop\DataScience\Data_Analytics\Course_Project_Data_Analysis\Mohirdev_Task_2_Certification\pipeline\pipeline.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
